# %% [markdown]
# ## Advanced_Transform_Core

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import OS and JSON Modules
import os, json

# %%
filename = ('Data/superhero_info.csv')
df = pd.read_csv(filename)
df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}

# %%
filename2 = ('Data/superhero_powers.csv')
df2 = pd.read_csv(filename2)
df2.head()
# Out:
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %% [markdown]
# ## Info Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hero|Publisher  463 non-null    object
#  1   Gender          463 non-null    object
#  2   Race            463 non-null    object
#  3   Alignment       463 non-null    object
#  4   Hair color      463 non-null    object
#  5   Eye color       463 non-null    object
#  6   Skin color      463 non-null    object
#  7   Measurements    463 non-null    object
# dtypes: object(8)
# memory usage: 29.1+ KB

# %%
df['Hero|Publisher'].value_counts()
# Out:
# Spider-Man|Marvel Comics       3
# Black Canary|DC Comics         2
# Nova|Marvel Comics             2
# Toxin|Marvel Comics            2
# Batman|DC Comics               2
#                               ..
# Fabian Cortez|Marvel Comics    1
# Exodus|Marvel Comics           1
# Evilhawk|Marvel Comics         1
# Evil Deadpool|Marvel Comics    1
# Zoom|DC Comics                 1
# Name: Hero|Publisher, Length: 457, dtype: int64

# %% [markdown]
# **Split Hero|Publisher**

# %%
df['Hero|Publisher'].str.split('|', expand=True)
# Out:
#                    0                  1
# 0             A-Bomb      Marvel Comics
# 1         Abe Sapien  Dark Horse Comics
# 2           Abin Sur          DC Comics
# 3        Abomination      Marvel Comics
# 4      Absorbing Man      Marvel Comics
# ..               ...                ...
# 458     Yellowjacket      Marvel Comics
# 459  Yellowjacket II      Marvel Comics
# 460             Yoda       George Lucas
# 461          Zatanna          DC Comics
# 462             Zoom          DC Comics
#
# [463 rows x 2 columns]

# %%
# save two new columns into dataframe
df[['Hero','Publisher']] = df['Hero|Publisher'].str.split('|', expand=True)
df.head()
# Out:
#                  Hero|Publisher Gender               Race Alignment  \
# 0          A-Bomb|Marvel Comics   Male              Human      good
# 1  Abe Sapien|Dark Horse Comics   Male      Icthyo Sapien      good
# 2            Abin Sur|DC Comics   Male            Ungaran      good
# 3     Abomination|Marvel Comics   Male  Human / Radiation       bad
# 4   Absorbing Man|Marvel Comics   Male              Human       bad
#
#   Hair color Eye color Skin color  \
# 0    No Hair    yellow    Unknown
# 1    No Hair      blue       blue
# 2    No Hair      blue        red
# 3    No Hair     green    Unknown
# 4    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# ...

# %%
# drop original column
df = df.drop(columns = ['Hero|Publisher'])
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#                                    Measurements           Hero  \
# 0  {'Height': '203.0 cm', 'Weight': '441.0 kg'}         A-Bomb
# 1   {'Height': '191.0 cm', 'Weight': '65.0 kg'}     Abe Sapien
# 2   {'Height': '185.0 cm', 'Weight': '90.0 kg'}       Abin Sur
# 3  {'Height': '203.0 cm', 'Weight': '441.0 kg'}    Abomination
# 4  {'Height': '193.0 cm', 'Weight': '122.0 kg'}  Absorbing Man
#
#            Publisher
# 0      Marvel Comics
# 1  Dark Horse Comics
# 2          DC Comics
# 3      Marvel Comics
# 4      Marvel Comics

# %% [markdown]
# **Make Dictionary**

# %%
coord = df.loc[0,"Measurements"]
print(type(coord))
coord
# Out:
# <class 'str'>
# "{'Height': '203.0 cm', 'Weight': '441.0 kg'}"

# %%
# Replace single quotes
coord = coord.replace("'",'"')
coord
# Out:
# '{"Height": "203.0 cm", "Weight": "441.0 kg"}'

# %%
# Use json.loads
fixed_coord = json.loads(coord)
print(type(fixed_coord))
fixed_coord
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %%
# use .str.replace to replace all single quotes
df['Measurements'] = df['Measurements'].str.replace("'",'"')

## Apple json.loads to full column
df['Measurements'] = df['Measurements'].apply(json.loads)
df['Measurements'].head()
# Out:
# 0    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 1     {'Height': '191.0 cm', 'Weight': '65.0 kg'}
# 2     {'Height': '185.0 cm', 'Weight': '90.0 kg'}
# 3    {'Height': '203.0 cm', 'Weight': '441.0 kg'}
# 4    {'Height': '193.0 cm', 'Weight': '122.0 kg'}
# Name: Measurements, dtype: object

# %%
## check a single value after transformation
test_coord = df.loc[0, 'Measurements']
print(type(test_coord))
test_coord
# Out:
# <class 'dict'>
# {'Height': '203.0 cm', 'Weight': '441.0 kg'}

# %% [markdown]
# **Splitting Dictionary**

# %%
height_weight = df['Measurements'].apply(pd.Series)
height_weight
# Out:
#        Height    Weight
# 0    203.0 cm  441.0 kg
# 1    191.0 cm   65.0 kg
# 2    185.0 cm   90.0 kg
# 3    203.0 cm  441.0 kg
# 4    193.0 cm  122.0 kg
# ..        ...       ...
# 458  183.0 cm   83.0 kg
# 459  165.0 cm   52.0 kg
# 460   66.0 cm   17.0 kg
# 461  170.0 cm   57.0 kg
# 462  185.0 cm   81.0 kg
#
# [463 rows x 2 columns]

# %%
# Add to dataframe and drop original column

df = pd.concat((df, height_weight), axis = 1)

df = df.drop(columns=['Measurements'])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height      463 non-null    object
#  9   Weight      463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# ...

# %% [markdown]
# **Fixing Height Column**

# %%
## adding expand=True
df['Height'].str.split(' ',expand=True)
# Out:
#          0   1
# 0    203.0  cm
# 1    191.0  cm
# 2    185.0  cm
# 3    203.0  cm
# 4    193.0  cm
# ..     ...  ..
# 458  183.0  cm
# 459  165.0  cm
# 460   66.0  cm
# 461  170.0  cm
# 462  185.0  cm
#
# [463 rows x 2 columns]

# %%
df[['Height_cm', 'Units']] = df['Height'].str.split(' ',expand=True)
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Height    Weight Height_cm Units
# 0         A-Bomb      Marvel Comics  203.0 cm  441.0 kg     203.0    cm
# 1     Abe Sapien  Dark Horse Comics  191.0 cm   65.0 kg     191.0    cm
# 2       Abin Sur          DC Comics  185.0 cm   90.0 kg     185.0    cm
# 3    Abomination      Marvel Comics  203.0 cm  441.0 kg     203.0    cm
# 4  Absorbing Man      Marvel Comics  193.0 cm  122.0 kg     193.0    cm

# %%
df = df.drop(columns = ['Units', 'Height'])
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Weight Height_cm
# 0         A-Bomb      Marvel Comics  441.0 kg     203.0
# 1     Abe Sapien  Dark Horse Comics   65.0 kg     191.0
# 2       Abin Sur          DC Comics   90.0 kg     185.0
# 3    Abomination      Marvel Comics  441.0 kg     203.0
# 4  Absorbing Man      Marvel Comics  122.0 kg     193.0

# %% [markdown]
# **Fixing Weight Column**

# %%
## adding expand=True
df['Weight'].str.split(' ',expand=True)
# Out:
#          0   1
# 0    441.0  kg
# 1     65.0  kg
# 2     90.0  kg
# 3    441.0  kg
# 4    122.0  kg
# ..     ...  ..
# 458   83.0  kg
# 459   52.0  kg
# 460   17.0  kg
# 461   57.0  kg
# 462   81.0  kg
#
# [463 rows x 2 columns]

# %%
df[['Weight_kg', 'Units2']] = df['Weight'].str.split(' ',expand=True)
df.head()
# Out:
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher    Weight Height_cm Weight_kg Units2
# 0         A-Bomb      Marvel Comics  441.0 kg     203.0     441.0     kg
# 1     Abe Sapien  Dark Horse Comics   65.0 kg     191.0      65.0     kg
# 2       Abin Sur          DC Comics   90.0 kg     185.0      90.0     kg
# 3    Abomination      Marvel Comics  441.0 kg     203.0     441.0     kg
# 4  Absorbing Man      Marvel Comics  122.0 kg     193.0     122.0     kg

# %%
df = df.drop(columns = ['Units2', 'Weight'])
df.head(2)
# Out:
#   Gender           Race Alignment Hair color Eye color Skin color        Hero  \
# 0   Male          Human      good    No Hair    yellow    Unknown      A-Bomb
# 1   Male  Icthyo Sapien      good    No Hair      blue       blue  Abe Sapien
#
#            Publisher Height_cm Weight_kg
# 0      Marvel Comics     203.0     441.0
# 1  Dark Horse Comics     191.0      65.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Gender      463 non-null    object
#  1   Race        463 non-null    object
#  2   Alignment   463 non-null    object
#  3   Hair color  463 non-null    object
#  4   Eye color   463 non-null    object
#  5   Skin color  463 non-null    object
#  6   Hero        463 non-null    object
#  7   Publisher   463 non-null    object
#  8   Height_cm   463 non-null    object
#  9   Weight_kg   463 non-null    object
# dtypes: object(10)
# memory usage: 36.3+ KB

# %% [markdown]
# **Converting Height and Weight to Float**

# %%
df['Height_cm'] = df['Height_cm'].astype(float)
print(df.dtypes)
# Out:
# Gender         object
# Race           object
# Alignment      object
# Hair color     object
# Eye color      object
# Skin color     object
# Hero           object
# Publisher      object
# Height_cm     float64
# Weight_kg      object
# dtype: object

# %%
df['Weight_kg'] = df['Weight_kg'].astype(float)
print(df.dtypes)
# Out:
# Gender         object
# Race           object
# Alignment      object
# Hair color     object
# Eye color      object
# Skin color     object
# Hero           object
# Publisher      object
# Height_cm     float64
# Weight_kg     float64
# dtype: object

# %%
df.to_csv('Data/advanced2_tf_data_pt1.csv', index = False)

# %% [markdown]
# ## Powers Dataframe

# %%
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 667 entries, 0 to 666
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hero_names  667 non-null    object
#  1   Powers      667 non-null    object
# dtypes: object(2)
# memory usage: 10.5+ KB
#     hero_names                                             Powers
# 0      3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1       A-Bomb  Accelerated Healing,Durability,Longevity,Super...
# 2   Abe Sapien  Agility,Accelerated Healing,Cold Resistance,Du...
# 3     Abin Sur                                 Lantern Power Ring
# 4  Abomination  Accelerated Healing,Intelligence,Super Strengt...

# %%
df2['Powers'].value_counts()
# Out:
# Intelligence                                                                                                                                                                                                                                                         8
# Durability,Super Strength                                                                                                                                                                                                                                            5
# Agility,Stealth,Marksmanship,Weapons Master,Stamina                                                                                                                                                                                                                  4
# ...

# %%
## adding expand=True
df2['powers_split'] = df2['Powers'].str.split(',',expand=False)

# %%
df2.head(2)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#                                         powers_split
# 0    [Agility, Super Strength, Stamina, Super Speed]
# 1  [Accelerated Healing, Durability, Longevity, S...

# %%
## exploding the column of lists

exploded = df2.explode('powers_split')
exploded[['hero_names','Powers', 'powers_split']].head(5)
# Out:
#   hero_names                                             Powers  \
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 0    3-D Man         Agility,Super Strength,Stamina,Super Speed
# 1     A-Bomb  Accelerated Healing,Durability,Longevity,Super...
#
#           powers_split
# 0              Agility
# 0       Super Strength
# 0              Stamina
# 0          Super Speed
# 1  Accelerated Healing

# %%
## saving the unique values from the exploded column
cols_to_make = exploded['powers_split'].dropna().unique()
cols_to_make
# Out:
# array(['Agility', 'Super Strength', 'Stamina', 'Super Speed',
#        'Accelerated Healing', 'Durability', 'Longevity', 'Camouflage',
#        'Self-Sustenance', 'Cold Resistance', 'Underwater breathing',
#        'Marksmanship', 'Weapons Master', 'Intelligence', 'Telepathy',
#        'Immortality', 'Reflexes', 'Enhanced Sight', 'Sub-Mariner',
#        'Lantern Power Ring', 'Invulnerability', 'Animation',
#        'Super Breath', 'Dimensional Awareness', 'Flight', 'Size Changing',
#        'Teleportation', 'Magic', 'Dimensional Travel',
#        'Molecular Manipulation', 'Energy Manipulation', 'Power Cosmic',
#        'Energy Absorption', 'Elemental Transmogrification',
#        'Fire Resistance', 'Natural Armor', 'Heat Resistance',
#        'Matter Absorption', 'Regeneration', 'Stealth', 'Power Suit',
#        'Energy Blasts', 'Energy Beams', 'Heat Generation', 'Danger Sense',
#        'Phasing', 'Force Fields', 'Hypnokinesis', 'Invisibility',
# ...

# %%
for col in cols_to_make:
    df2[col] = df2['Powers'].str.contains(col)
df2.head()
# Out:
# /var/folders/fp/jpcv35096h9d0ylkqvbwx2xm0000gn/T/ipykernel_5299/4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# /var/folders/fp/jpcv35096h9d0ylkqvbwx2xm0000gn/T/ipykernel_5299/4218022820.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df2[col] = df2['Powers'].str.contains(col)
# ...

# %%
# Drop Powers Column

df2 = df2.drop(columns=['Powers', 'powers_split'])
df2.to_csv('Data/advanced_tf_data_pt1.csv', index = False)

# %% [markdown]
# ## Merging

# %%
# Hero Info DF
left_df = pd.read_csv('Data/advanced2_tf_data_pt1.csv')
# Powers DF
right_df = pd.read_csv('Data/advanced_tf_data_pt1.csv')

# %%
## merging with different column names
merged = pd.merge(left_df, right_df, left_on='Hero', right_on='hero_names')
merged.info()
pd.set_option('display.max_columns', None)
merged.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 463 entries, 0 to 462
# Columns: 178 entries, Gender to Changing Armor
# dtypes: bool(167), float64(2), object(9)
# memory usage: 118.9+ KB
#   Gender               Race Alignment Hair color Eye color Skin color  \
# 0   Male              Human      good    No Hair    yellow    Unknown
# 1   Male      Icthyo Sapien      good    No Hair      blue       blue
# 2   Male            Ungaran      good    No Hair      blue        red
# 3   Male  Human / Radiation       bad    No Hair     green    Unknown
# 4   Male              Human       bad    No Hair      blue    Unknown
#
#             Hero          Publisher  Height_cm  Weight_kg     hero_names  \
# 0         A-Bomb      Marvel Comics      203.0      441.0         A-Bomb
# 1     Abe Sapien  Dark Horse Comics      191.0       65.0     Abe Sapien
# 2       Abin Sur          DC Comics      185.0       90.0       Abin Sur
# ...

# %%
merged.to_csv('Data/advanced_merge_tf_data_pt2.csv')

# %% [markdown]
# **Compare the average weight of super heroes who have Super Speed to those who do not.**

# %%
means = merged.groupby('Super Speed')['Weight_kg'].mean().sort_values(ascending = False)
means
# Out:
# Super Speed
# True     129.404040
# False    101.773585
# Name: Weight_kg, dtype: float64

# %% [markdown]
# * Those with super speed have higher average weight than those who do not.

# %% [markdown]
# **What is the average height of heroes for each publisher?**

# %%
means2 = merged.groupby('Publisher')['Height_cm'].mean().sort_values(ascending = False)
means2
# Out:
# Publisher
# Image Comics         211.000000
# Marvel Comics        191.546128
# DC Comics            181.923913
# Star Trek            181.500000
# Team Epic TV         180.750000
# Unknown              178.000000
# Dark Horse Comics    176.909091
# Shueisha             171.500000
# George Lucas         159.600000
# Name: Height_cm, dtype: float64

# %% [markdown]
# * Image Comics has the tallet super heroes
# * George Lucas has the shortest super heroes
